# %%
from numpy.random import seed
from numpy.random import randint
import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd
import string, random

# %%
#Begin with the base code for quick sort as described in chapter 4 of Grokking Algorithms (Bhargava 2016).

def quicksort(array):
    if len(array) <2:
        return array #Base case: arrays with 0 or 1 elements are already sorted
    else:
        pivot = array[0] #Recursive case. NOTE: always starting with index 0 is not efficient
        less = [i for i in array[1:] if i <= pivot] #sub-array of all elements less than pivot
        greater = [i for i in array[1:] if i > pivot] #sub-array of all elements greater than pivot
        
        return quicksort(less) + [pivot] + quicksort(greater)

# %%
#Generate first name by randomly picking ten characters (e.g. abcdefghij etc), 
#last name by randomly picking another ten characters (klmnopqrstu etc)
#and state should be any two letters state from 50 US stats (e.g. IL, CA, AZ etc), 
#you can store all 50 states in one array and then use that by randomly assigning a state to a person.

persons = [f'Person {i}' for i in range(1, 51)]

persons

firstNames = set()

while len(firstNames) <= 50:
    firstNames.add(''.join(random.sample(string.ascii_lowercase,10)).capitalize())


lastNames = set()
while len(lastNames) <= 50:
    lastNames.add(''.join(random.sample(string.ascii_lowercase,10)).capitalize())


#FYI, for anyone that reads this, I found this array at 
# https://gist.github.com/JeffPaine/3083347#file-us_state_abbreviations-py
#Makes it much easier than typing them all out in the future!


states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
#Create a 'person' data structure (use arrays or lists or dictionary) that has first name, 
#last name, and address (address should be only two characters state e.g. IL, CA, AZ, TX etc.).

people = dict(zip(persons,zip(firstNames, lastNames,states)))
peopleDF = pd.DataFrame.from_dict(people, orient = 'index')
peopleDF.columns = ['First Name', 'Last Name', 'State']
peopleDF
# Out:
#            First Name   Last Name State
# Person 1   Wnvmfyrcbe  Lqaodcsmgx    AL
# Person 2   Rnksqwhbfz  Acrpyzstwe    AK
# Person 3   Arvjqfegdw  Ihblxuwmzc    AZ
# Person 4   Prbwdtanvx  Venhfqwlgp    AR
# Person 5   Uribvpehzl  Ytgknxzwsq    CA
# Person 6   Fmbrljzxko  Xdinjuyvmo    CO
# Person 7   Libzshnojd  Zkclbqwsmv    CT
# Person 8   Pxyqvjksog  Vjocdypnak    DE
# Person 9   Kwvmpdezai  Dvubwiqajk    FL
# Person 10  Rzhncmfeks  Ktesqmnvyg    GA
# Person 11  Zcenkxgalq  Sapgfnoxib    HI
# Person 12  Vsicxyuwma  Ezahucwxld    ID
# Person 13  Fltjnrgimd  Ozsmtbryen    IL
# Person 14  Gbwkcianyx  Piomndgust    IN
# Person 15  Gpfkuzswxi  Hlusyzjoar    IA
# Person 16  Pgcqyvjnsa  Zhwnkdevqj    KS
# Person 17  Mkczgpuhrt  Hsdnvurxfw    KY
# Person 18  Egvuwsricm  Jctmyuknxq    LA
# Person 19  Udmzhbtjsy  Jzoanfxbqv    ME
# Person 20  Ybotlsjewg  Wrqtbielvn    MD
# Person 21  Pqwfrziyeb  Ymldfhbscn    MA
# Person 22  Fsrxmongwe  Clxunmovqr    MI
# Person 23  Qvopcujgrh  Myvnzplrwd    MN
# Person 24  Xsucktfvqp  Hgxyblvnfo    MS
# Person 25  Trmvjalygz  Phoncdmzri    MO
# Person 26  Ibkwqfadme  Nghuryqkcj    MT
# Person 27  Owesdkrpgn  Zxlgmfjsoi    NE
# Person 28  Bsajoxeqnz  Qyrtedlwhi    NV
# Person 29  Xaltgkczqm  Dxksfoaimp    NH
# Person 30  Htxvbpkfyz  Gbzfauwyhk    NJ
# Person 31  Lyzeufmnqi  Lwfsuzdiak    NM
# Person 32  Ujkwixtbnq  Izfgtdwyje    NY
# Person 33  Ewikdhymns  Bwkniudymr    NC
# Person 34  Wxbjyszkuh  Cmnwthjarz    ND
# Person 35  Rqfjbvxzwm  Qdheipofgb    OH
# Person 36  Mlrjpxhbfi  Qgseubpjcr    OK
# Person 37  Nqwhbusxzj  Wrymtnpgaq    OR
# Person 38  Imebstckdn  Auiqwerlgo    PA
# Person 39  Zfwngdekhi  Bzsdgthkoe    RI
# Person 40  Yiqvmtopda  Qzftpdyvex    SC
# Person 41  Hejynukpmo  Nroiqhtcbp    SD
# Person 42  Mhsnocxilw  Niecpbltsk    TN
# Person 43  Dxuyrojatk  Rexapumvwk    TX
# Person 44  Dmjuxqfwph  Unsptdkyac    UT
# Person 45  Lcwbhzexqi  Xfjbzklvcw    VT
# Person 46  Gqjyveuztc  Rzasvyqwni    VA
# Person 47  Cbxnkelhjg  Psgruoqyil    WA
# Person 48  Thypljzgmd  Bugcojzyxt    WV
# Person 49  Ucmbdnjhif  Zsymvcuqbg    WI
# Person 50  Xhfdscytkl  Xbhtvfcqun    WY
