# %%
from numpy.random import seed
from numpy.random import randint
import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd
import string, random

# %%
#Begin with the base code for quick sort as described in chapter 4 of Grokking Algorithms (Bhargava 2016).

def quicksort(array):
    if len(array) <2:
        return array #Base case: arrays with 0 or 1 elements are already sorted
    else:
        pivot = array[0] #Recursive case. NOTE: always starting with index 0 is not efficient
        less = [i for i in array[1:] if i <= pivot] #sub-array of all elements less than pivot
        greater = [i for i in array[1:] if i > pivot] #sub-array of all elements greater than pivot
        
        return quicksort(less) + [pivot] + quicksort(greater)

# %%
#Generate first name by randomly picking ten characters (e.g. abcdefghij etc), 
#last name by randomly picking another ten characters (klmnopqrstu etc)
#and state should be any two letters state from 50 US stats (e.g. IL, CA, AZ etc), 
#you can store all 50 states in one array and then use that by randomly assigning a state to a person.

persons = [f'Person {i}' for i in range(1, 51)]

persons

firstNames = set()

while len(firstNames) <= 50:
    firstNames.add(''.join(random.sample(string.ascii_lowercase,10)).capitalize())


lastNames = set()
while len(lastNames) <= 50:
    lastNames.add(''.join(random.sample(string.ascii_lowercase,10)).capitalize())


#FYI, for anyone that reads this, I found this array at 
# https://gist.github.com/JeffPaine/3083347#file-us_state_abbreviations-py
#Makes it much easier than typing them all out in the future!


states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
#Create a 'person' data structure (use arrays or lists or dictionary) that has first name, 
#last name, and address (address should be only two characters state e.g. IL, CA, AZ, TX etc.).

people = dict(zip(persons,zip(firstNames, lastNames,states)))
peopleDF = pd.DataFrame.from_dict(people, orient = 'index')
peopleDF.columns = ['First Name', 'Last Name', 'State']
peopleDF
# Out:
#            First Name   Last Name State
# Person 1   Tkjupolvnx  Cmqnhgzoul    AL
# Person 2   Fwgxlmuspd  Lzyqpbousw    AK
# Person 3   Aqdmolbyhu  Motrxwkcap    AZ
# Person 4   Cautkfvjxb  Zguqhcnvwy    AR
# Person 5   Alsrcqwbzp  Wmzbifredy    CA
# Person 6   Pzxvisylbm  Yzhvkwrtqu    CO
# Person 7   Wdxnbzikvt  Wxjabvhigm    CT
# Person 8   Frhmdpyweo  Ckjlfuexmv    DE
# Person 9   Ardeomfpsy  Baqhjuvczx    FL
# Person 10  Ykomsgzwni  Qszcwrnkmi    GA
# Person 11  Dljyugizco  Ndcamwqokb    HI
# Person 12  Ykopxnqcit  Gmcwbpsqen    ID
# Person 13  Ginzdajmtl  Hlzknrtife    IL
# Person 14  Eukgqdlbhi  Qjbmcshfei    IN
# Person 15  Rjiqgtpoas  Qknblvfupd    IA
# Person 16  Wvyxmfucro  Qixdsntheu    KS
# Person 17  Txfmnruays  Saqtdilmgh    KY
# Person 18  Fpcwdtgjuy  Mvxrstonew    LA
# Person 19  Swvjprfguk  Fqvsktxgjd    ME
# Person 20  Pdabnqlhsc  Lgdwtxkpfh    MD
# Person 21  Ufnyxwihdr  Rxmpktwado    MA
# Person 22  Phnzjofctw  Abzxvcldqn    MI
# Person 23  Qbotwxhnjr  Mghbazwnus    MN
# Person 24  Dhxfpowtig  Uxifpeogzt    MS
# Person 25  Qwfcvyrhmt  Ygjmqicpfd    MO
# Person 26  Ifoqljcnxm  Dcwkgsmpvt    MT
# Person 27  Oxdniypmje  Mcqlwgfjvt    NE
# Person 28  Ywkjqpgumz  Ypdshtvufb    NV
# Person 29  Qiflmbyrzj  Rwozgscixk    NH
# Person 30  Fsykdxehro  Umqcfhvetn    NJ
# Person 31  Axvdjgnkpm  Bwivtunshd    NM
# Person 32  Ecxbaptzwf  Exlngmrupz    NY
# Person 33  Yavlgqszxt  Jnxeyiqlob    NC
# Person 34  Xhdboqpvir  Owplfjmaut    ND
# Person 35  Ayubvojpsf  Bhnmsycgvf    OH
# Person 36  Phbmfljtzi  Nbwsqxyuld    OK
# Person 37  Hadeymqxrw  Cbeikmazvl    OR
# Person 38  Xjnfdhuztg  Zpesmqgdnk    PA
# Person 39  Xnwmdyqfkb  Jufsbixrzp    RI
# Person 40  Lprixtmfsq  Qgvuweskzn    SC
# Person 41  Uxabyldrew  Fhwngbjyrd    SD
# Person 42  Nsitjvkcye  Dckblqiare    TN
# Person 43  Rkpscfnaxy  Tmexklisqw    TX
# Person 44  Hqmzyjtnfg  Lhnuzfdyqo    UT
# Person 45  Pgqyikwczv  Vdhspauzib    VT
# Person 46  Rlzhnkebwo  Gpsnjhxblv    VA
# Person 47  Eanxiqtlgr  Qgnwokcbzx    WA
# Person 48  Pmhfzjtwev  Pauosymkct    WV
# Person 49  Unvaxztbyl  Iyhugodnve    WI
# Person 50  Cikegdmhvp  Nealzokgvm    WY

# %%
#Once the data is ready, use quicksort to sort the data by first name, 
#then last name, and then state.
#Use dataframe to output the sorted result set

start = time.clock()
for i in range(1000):
    peopleDF.apply(quicksort, 0)
stop = time.clock()

quickTime = (stop - start)/1000

peopleSort =     peopleDF.apply(quicksort, 0)
peopleSort
# Out:
#            First Name   Last Name State
# Person 1   Alsrcqwbzp  Abzxvcldqn    AK
# Person 2   Aqdmolbyhu  Baqhjuvczx    AL
# Person 3   Ardeomfpsy  Bhnmsycgvf    AR
# Person 4   Axvdjgnkpm  Bwivtunshd    AZ
# Person 5   Ayubvojpsf  Cbeikmazvl    CA
# Person 6   Cautkfvjxb  Ckjlfuexmv    CO
# Person 7   Cikegdmhvp  Cmqnhgzoul    CT
# Person 8   Dhxfpowtig  Dckblqiare    DE
# Person 9   Dljyugizco  Dcwkgsmpvt    FL
# Person 10  Eanxiqtlgr  Exlngmrupz    GA
# Person 11  Ecxbaptzwf  Fhwngbjyrd    HI
# Person 12  Eukgqdlbhi  Fqvsktxgjd    IA
# Person 13  Fpcwdtgjuy  Gmcwbpsqen    ID
# Person 14  Frhmdpyweo  Gpsnjhxblv    IL
# Person 15  Fsykdxehro  Hlzknrtife    IN
# Person 16  Fwgxlmuspd  Iyhugodnve    KS
# Person 17  Ginzdajmtl  Jnxeyiqlob    KY
# Person 18  Hadeymqxrw  Jufsbixrzp    LA
# Person 19  Hqmzyjtnfg  Lgdwtxkpfh    MA
# Person 20  Ifoqljcnxm  Lhnuzfdyqo    MD
# Person 21  Lprixtmfsq  Lzyqpbousw    ME
# Person 22  Nsitjvkcye  Mcqlwgfjvt    MI
# Person 23  Oxdniypmje  Mghbazwnus    MN
# Person 24  Pdabnqlhsc  Motrxwkcap    MO
# Person 25  Pgqyikwczv  Mvxrstonew    MS
# Person 26  Phbmfljtzi  Nbwsqxyuld    MT
# Person 27  Phnzjofctw  Ndcamwqokb    NC
# Person 28  Pmhfzjtwev  Nealzokgvm    ND
# Person 29  Pzxvisylbm  Owplfjmaut    NE
# Person 30  Qbotwxhnjr  Pauosymkct    NH
# Person 31  Qiflmbyrzj  Qgnwokcbzx    NJ
# Person 32  Qwfcvyrhmt  Qgvuweskzn    NM
# Person 33  Rjiqgtpoas  Qixdsntheu    NV
# Person 34  Rkpscfnaxy  Qjbmcshfei    NY
# Person 35  Rlzhnkebwo  Qknblvfupd    OH
# Person 36  Swvjprfguk  Qszcwrnkmi    OK
# Person 37  Tkjupolvnx  Rwozgscixk    OR
# Person 38  Txfmnruays  Rxmpktwado    PA
# Person 39  Ufnyxwihdr  Saqtdilmgh    RI
# Person 40  Unvaxztbyl  Tmexklisqw    SC
# Person 41  Uxabyldrew  Umqcfhvetn    SD
# Person 42  Wdxnbzikvt  Uxifpeogzt    TN
# Person 43  Wvyxmfucro  Vdhspauzib    TX
# Person 44  Xhdboqpvir  Wmzbifredy    UT
# Person 45  Xjnfdhuztg  Wxjabvhigm    VA
# Person 46  Xnwmdyqfkb  Ygjmqicpfd    VT
# Person 47  Yavlgqszxt  Ypdshtvufb    WA
# Person 48  Ykomsgzwni  Yzhvkwrtqu    WI
# Person 49  Ykopxnqcit  Zguqhcnvwy    WV
# Person 50  Ywkjqpgumz  Zpesmqgdnk    WY

# %%
#Capture quicksort time, then use other sorting algorithms on the same data set 
#e.g. merge sort, bubble sort, insertion sort etc (if you don't know them, Google 
#them and use their code from internet).

start = time.clock()
for i in range(1000): #running the function 1K times to take the average time for all runs
    peopleDF.sort_values(by = ['First Name', 'Last Name', 'State'])
stop = time.clock()
pandaTime = (stop - start)/1000
# Out:
# 0.001522101000000001

# %%
#Capture time for every sorting algorithm that you have used (minimum is to use 
#any two including quicksort) and then create a graph comparing times for all of 
#the algorithms that you have used

objects = ('Grokken Quicksort', 'Pandas Sort')
y_pos = np.arange(len(objects))
performance = [quickTime, pandaTime]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Average Time to Execute')
plt.title('Sorting Performance')
 
plt.show()

# %% [markdown]
# ## Executive Summary
#
# Running an algorithm once does not often give a true picture of its efficiency. A single claculation of runtime can often produce misleading results. For instance, when we timed the above sorting algorithms several times in a row, each proved the fastest on individual runs, with no clear indication as to why.
#
# To smooth the results and understand which one delivers the most efficiency in the long run, we ran each 1,000 times and took an average of the results. By doing so, we were able to show that, on balance, the built-in Pandas sorting algorithm performs better over time.
